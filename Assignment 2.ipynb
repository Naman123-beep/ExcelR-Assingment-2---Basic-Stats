# %% [markdown]
# ## Basic Statistic level 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.Series([24.23, 25.53, 25.41, 24.14, 29.62, 28.25, 25.81, 24.39, 40.26, 32.95, 91.36, 25.99, 39.42, 26.71])

# %%
name=['Allied Signal', 'Bankers Trust', 'General Mills', 'ITT Industries', 'J.P.Morgan & Co.', 'Lehman Brother', 'Marriot', 'MCI', 'Merrill Lynch', 'Microsoft', 'Morgan Stanely', 'Sun Microsystems', 'Travelers', 'US Airways']

# %%
#pie plo8
plt.figure(figsize=(8,8))
plt.pie(df,labels=name,autopct='%1.0f%%')
plt.show()

# %%
#box plot to find outliars
sns.boxplot(df)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
#Mean
df.mean()
# Out:
# 33.14785714285714

# %%
#Vairance
df.var()
# Out:
# 308.98852582417584

# %%
#Standard Deviation
df.std()
# Out:
# 17.578069456688805

# %% [markdown]
# #  Set 2 - Q2

# %%
from scipy import stats
from scipy.stats import norm
import numpy as np

# %% [markdown]
# # A

# %%
# p(X>44); Employees older than 44 yrs of age
1-stats.norm.cdf(44,loc=38,scale=6)
# Out:
# 0.15865525393145707

# %%
# p(38
stats.norm.cdf(44,38,6)-stats.norm.cdf(38,38,6)
# Out:
# 0.3413447460685429

# %% [markdown]
# # B

# %%
# P(X<30); Employees under 30 yrs of age
stats.norm.cdf(30,38,6)
# Out:
# 0.09121121972586788

# %%
# No. of employees attending training program from 400 nos. is N*P(X<30)
400*stats.norm.cdf(30,38,6)
# Out:
# 36.484487890347154

# %% [markdown]
# # Set 2 Q5

# %%
# Mean profits from two different divisions of a company = Mean1 + Mean2
Mean = 5+7
print('Mean Profit is Rs', Mean*45,'Million')
# Out:
# Mean Profit is Rs 540 Million

# %%
# Variance of profits from two different divisions of a company = SD^2 = SD1^2 + SD2^2
SD = np.sqrt((9)+(16))
print('Standard Deviation is Rs', SD*45, 'Million')
# Out:
# Standard Deviation is Rs 225.0 Million

# %% [markdown]
# # Q5 - A

# %%
#Specify a Rupee range (centered on the mean) such that it contains 95% probability for the annual profit of the company.
print('Range is Rs',(stats.norm.interval(0.95,540,225)),'in Millions')
# Out:
# Range is Rs (99.00810347848784, 980.9918965215122) in Millions

# %% [markdown]
# # Q5 - B

# %%
#Specify the 5th percentile of profit (in Rupees) for the company
# To compute 5th Percentile, we use the formula X=μ + Zσ; wherein from z table,
X= 540+(-1.645)*(225)
print('5th percentile of profit (in Million Rupees) is',np.round(X,))
# Out:
# 5th percentile of profit (in Million Rupees) is 170.0

# %% [markdown]
# # Q5 - C

# %%
# Probability of Division 1 making a loss P(X<0)
stats.norm.cdf(0,5,3)
# Out:
# 0.0477903522728147

# %%
# Probability of Division 2 making a loss P(X<0)
stats.norm.cdf(0,7,4)
# Out:
# 0.040059156863817086
